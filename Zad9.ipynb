# %% [markdown]
# <a href="https://colab.research.google.com/github/justyna-b/175IC-machine-learning/blob/main/Zad9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
import plotly.express as px
from sklearn.ensemble import IsolationForest

sns.set(font_scale=1.2)
np.random.seed(32)
data = make_blobs(n_samples=700, cluster_std=2.0, random_state=10)[0]

forest = IsolationForest(n_estimators=300, contamination=0.05)
predict = forest.fit_predict(data)
all_data = pd.DataFrame(data, columns=['x', 'y'])
all_data['outliner'] = predict
 
plt.figure(figsize=(10, 5))
inliners = all_data[all_data.outliner == 1].drop(columns='outliner')
outliners = all_data[all_data.outliner == -1].drop(columns='outliner')
  
plt.scatter(x=inliners.x, y=inliners.y, edgecolors='blue')
plt.scatter(x=outliners.x, y=outliners.y, edgecolors='green')
legend = plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.
